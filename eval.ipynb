# %%
import warnings
warnings.filterwarnings('ignore')
from deepchecks.tabular.suites import full_suite
from skopt.plots import plot_objective, plot_evaluations, plot_convergence, plot_regret
from configs import music,santander_customer_satisfaction,Wids2021,ionosphere,fetal_health,santander,California,playground,Wine,Medicalpremium,Avocado
from sklearn.metrics import classification_report,roc_auc_score,accuracy_score
import pickle
from skopt import dump, load
from matplotlib import pyplot as plt
import numpy as np
import glob
import pandas as pd
suite = full_suite()
def is_float(element) -> bool:
    try:
        float(element)
        return True
    except ValueError:
        return False
import seaborn as sns
sns.set()

# %%
def get_results(config_names,q=1):
    reg = []
    cla = []
    for config_name in config_names:
        with open(config_name, 'rb') as inp:
            config2 = pickle.load(inp)
            h = config2['history'][-1]            
            if "mean_squared_error" in h:
                mean_squared_error, r2, _ , mean_squared_error_alpha_0,_,r2_alpha0,run_time,size,fet =  [round(float(row),8) for row in h.replace(","," ").split(" ") if is_float(row)]
                reg.append([config_name.split(".pkl")[0].split("/")[1],mean_squared_error, r2 , mean_squared_error_alpha_0,r2_alpha0,run_time,size,fet])
            else:
                auc, auc_alpha0,run_time,size,fet =  [round(float(row),4) for row in h.replace(","," ").split(" ") if is_float(row)]
                y_pred_without_random = np.concatenate([config2['history'][row]['y_pred_without_random'] for row in range(5)],0)
                y_true =  np.concatenate([config2['history'][row]['y_val'] for row in range(5)],0)
                y_pred = np.concatenate([config2['history'][row]['y_pred'] for row in range(5)],0)
                acc1 = accuracy_score(y_true.astype(int),y_pred.argmax(1).astype(int))
                acc2 = accuracy_score(y_true.astype(int),y_pred_without_random.argmax(1).astype(int))
                cla.append([config_name.split(".pkl")[0].split("/")[1],auc,auc_alpha0,acc1,acc2,run_time,size,fet])
    df_cla = pd.DataFrame(cla,columns=['dataset',f'best_auc_{q}',f'baseline_auc_{q}',f'best_acc_{q}',f'baseline_acc_{q}',f'run_time_{q}',"total_size",'features'])
    df_reg = pd.DataFrame(reg,columns=['dataset',f'best_mse_{q}',f'best_r2_{q}',f'baseline_mse_{q}',f'baseline_r2_{q}',f'run_time_{q}',"total_size",'features'])
    return df_cla,df_reg

# %%
df_cla1,df_reg1 = get_results(glob.glob('outputs/*.pkl'),1)
df_cla3,df_reg3 = get_results(glob.glob('outputs3/*.pkl'),3)

# %%
df_reg = pd.merge(df_reg3[['dataset','best_mse_3','best_r2_3']],df_reg1,on='dataset')
df_reg
# Out:
#            dataset  best_mse_3  best_r2_3  best_mse_1  best_r2_1  \
# 0        santander   57.184594   0.156429   57.486705   0.151972
# 1       California    0.003962   0.702437    0.004030   0.697351
# 2       playground    0.544478  -0.020038    0.529683   0.007679
# 3             Wine    0.412306   0.364495    0.424798   0.345241
# 4  Medical premium    0.081111   0.792025    0.086531   0.778126
# 5          Avocado    0.074305   0.541720    0.076187   0.530114
#
#    baseline_mse_1  baseline_r2_1   run_time_1  total_size  features
# 0       58.040977       0.143795  1406.927880      4459.0     998.0
# 1        0.004050       0.695868  1013.466887     20640.0      14.0
# 2        0.719841      -0.348569   688.369511      1000.0      15.0
# 3        0.479220       0.261357   671.528247      1143.0      13.0
# 4        0.085076       0.781858   692.984474       986.0      11.0
# 5        0.076251       0.529720  1034.086154     18249.0       9.0

# %%
df_reg.to_csv("df_reg.csv",index=False)

# %%
plt.figure(figsize=[20,10])
for row in range(6):
    d = df_reg.loc[row]['dataset']
    if d=="playground":
        continue
    plt.subplot(2,3,row+1)
    plt.scatter(['baseline_r2_1','best_r2_1','best_r2_3'],df_reg[['baseline_r2_1','best_r2_1','best_r2_3']].loc[row],s=[140,140,140])
    plt.plot(['baseline_r2_1','best_r2_1','best_r2_3'],df_reg[['baseline_r2_1','best_r2_1','best_r2_3']].loc[row])

    plt.title(f"r2 - {d}")

# %%
plt.figure(figsize=[20,10])
for row in range(6):
    d = df_reg.loc[row]['dataset']
    if d=="playground":
        continue
    plt.subplot(2,3,row+1)
    plt.scatter(['baseline_mse_1','best_mse_1','best_mse_3'],df_reg[['baseline_mse_1','best_mse_1','best_mse_3']].loc[row],s=[140,140,140])
    plt.plot(['baseline_mse_1','best_mse_1','best_mse_3'],df_reg[['baseline_mse_1','best_mse_1','best_mse_3']].loc[row])

    plt.title(f"mean_squared_error - {d}")
plt.show()

# %%
df_class = pd.merge(df_cla3.drop(["total_size","features","baseline_auc_3","run_time_3"],axis=1),df_cla1,on='dataset')
df_class.to_csv("df_class.csv",index=False)
df_class
# Out:
#                            dataset  best_auc_3  best_acc_3  baseline_acc_3  \
# 0                            music      0.8986    0.473272        0.463158
# 1                       ionosphere      0.9433    0.903134        0.903134
# 2  santander_customer_satisfaction      0.8241    0.960431        0.960431
# 3                             Wids      0.8192    0.812972        0.810997
# 4                     fetal_health      0.9653    0.911571        0.908749
#
#    best_auc_1  baseline_auc_1  best_acc_1  baseline_acc_1  run_time_1  \
# 0      0.8967          0.8918    0.469327        0.463158   1239.4510
# 1      0.9279          0.9190    0.866097        0.903134     21.6875
# 2      0.8214          0.8214    0.960431        0.960431   3105.5964
# 3      0.8130          0.8105    0.810360        0.810997   4581.4178
# 4      0.9583          0.9528    0.914864        0.908749    704.3366
#
#    total_size  features
# 0     17996.0      15.0
# 1       351.0      35.0
# 2     76020.0     370.0
# 3    130157.0     162.0
# 4      2126.0      22.0

# %%
plt.figure(figsize=[20,10])
for row in range(5):
    plt.subplot(2,3,row+1)
    plt.scatter(['baseline_auc_1','best_auc_1','best_auc_3'],df_class[['baseline_auc_1','best_auc_1','best_auc_3']].loc[row],s=[140,140,140])
    plt.plot(['baseline_auc_1','best_auc_1','best_auc_3'],df_class[['baseline_auc_1','best_auc_1','best_auc_3']].loc[row])
    d = df_class.loc[row]['dataset']
    plt.title(f"AUC - {d}")

# %%
plt.figure(figsize=[20,10])
for row in range(5):
    plt.subplot(2,3,row+1)
    plt.scatter(['baseline_acc_1','best_acc_1','best_acc_3'],df_class[['baseline_acc_1','best_acc_1','best_acc_3']].loc[row],s=[140,140,140])
    plt.plot(['baseline_acc_1','best_acc_1','best_acc_3'],df_class[['baseline_acc_1','best_acc_1','best_acc_3']].loc[row])
    d = df_class.loc[row]['dataset']
    plt.title(f"AUC - {d}")

# %%
def get_results_kfold(config_names,q=1):
    reg = []
    cla = []
    for config_name in config_names:
        name = config_name.split(".pkl")[0].split("/")[1]
        with open(config_name, 'rb') as inp:
            config2 = pickle.load(inp)
            h = config2['history']
            for c in range(5):
                fold = h[c]
                try:
                    cla.append([name,c,fold['auc'],fold['acc'],fold['alpha'],fold['iter']])
                except:
                    break
    return pd.DataFrame(cla,columns=['dataset',f'fold',f'auc_{q}',f'acc_{q}',f"alpha_{q}",f'N_{q}'])
    # return df_cla,df_reg

# %%
df_1 = get_results_kfold(glob.glob('outputs/*.pkl'),1)
df_3 = get_results_kfold(glob.glob('outputs3/*.pkl'),3)
df = pd.merge(df_1,df_3,on=['dataset','fold'])

# %%
df
# Out:
#                             dataset  fold      auc_1     acc_1   alpha_1  N_1  \
# 0                        ionosphere     0   0.960684  0.929577  0.118485   41
# 1                        ionosphere     1   0.943111  0.871429  0.172630   23
# 2                        ionosphere     2   0.889778  0.785714  0.109640    9
# 3                        ionosphere     3   0.963556  0.942857  0.083743   85
# 4                        ionosphere     4   0.891556  0.800000  0.179071   59
# 5                             music     0   0.902137  0.486944  0.086861   91
# 6                             music     1   0.894580  0.465963  0.090382   64
# 7                             music     2   0.895172  0.471242  0.095431  100
# 8                             music     3   0.896971  0.451514  0.114076   96
# 9                             music     4   0.895873  0.470964  0.089574   92
# 10  santander_customer_satisfaction     0   0.807890  0.960471  0.050251   71
# 11  santander_customer_satisfaction     1   0.825533  0.960471  0.063141   68
# 12  santander_customer_satisfaction     2   0.830509  0.960405  0.083455  100
# 13  santander_customer_satisfaction     3   0.823082  0.960405  0.048885   19
# 14  santander_customer_satisfaction     4   0.829003  0.960405  0.022032  100
# 15                             Wids     0   0.815659  0.810157  0.100035   85
# 16                             Wids     1   0.812970  0.808313  0.099422  100
# 17                             Wids     2   0.814980  0.813568  0.073086   94
# 18                             Wids     3   0.809948  0.811571  0.096826  100
# 19                             Wids     4   0.814215  0.808190  0.113754   86
# 20                     fetal_health     0   0.947969  0.896714  0.060838   51
# 21                     fetal_health     1   0.954790  0.920000  0.126215  100
# 22                     fetal_health     2   0.954120  0.908235  0.069480   69
# 23                     fetal_health     3   0.962974  0.912941  0.070368   37
# 24                     fetal_health     4   0.980869  0.936471  0.088739   99
# 25                        santander     0  48.749347  0.140367  0.000000  100
# 26                        santander     1  59.641573  0.148312  0.007369   36
# 27                        santander     2  58.389102  0.162219  0.025811   59
# 28                        santander     3  65.732152  0.186608  0.032246   89
# 29                        santander     4  54.918470  0.101755  0.016634   75
# 30                       California     0   0.004184  0.680720  0.014920   88
# 31                       California     1   0.004109  0.699197  0.018534   91
# 39   0.633823 -0.036114  0.399613   69
# 40   0.347777  0.375033  0.266464  100
# 41   0.487096  0.338552  0.217993   89
# 42   0.411346  0.393005  0.310415   71
# 43   0.417919  0.387732  0.267117   70
# 44   0.397352  0.324506  0.168920   73
# 45   0.052788  0.876209  0.125622   48
# 46   0.113685  0.753601  0.068713  100
# 47   0.084639  0.760348  0.284497  100
# 48   0.096397  0.718917  0.115433   75
# 49   0.058189  0.836054  0.194861  100
# 50   0.076387  0.524572  0.337327  100
# 51   0.075841  0.536289  0.269703  100
# 52   0.071984  0.552573  0.242790  100
# 53   0.072551  0.554562  0.358302   58
# 54   0.074764  0.540270  0.342413   76

# %%
cla = list(df_class.dataset)
plt.figure(figsize=[20,10])
j = 0
for i,mini in df.groupby(["dataset"]):
    if not i in cla:
        continue
    if len(mini)>4:
        plt.subplot(2,4,j+1)
        j+=1
        ax = sns.boxplot(data=mini[['dataset','auc_1','auc_3']], 
                     palette='Set3', 
                     linewidth=1.2, 
                     fliersize=2, 
                     flierprops=dict(marker='o', markersize=4))
        plt.title(i)
for i,mini in df.groupby(["dataset"]):
    if not i in cla:
        continue
    if len(mini)>4:
        plt.subplot(2,4,j+1)
        j+=1
        ax = sns.boxplot(data=mini[['dataset','acc_1','acc_3']], 
                     palette='Set3', 
                     linewidth=1.2, 
                     fliersize=2, 
                     flierprops=dict(marker='o', markersize=4))
        plt.title(i)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-370-3dc96b0f8145> in <module>
#      18         continue
#      19     if len(mini)>4:
# ---> 20         plt.subplot(2,4,j+1)
#      21         j+=1
#      22         ax = sns.boxplot(data=mini[['dataset','acc_1','acc_3']],
#
# ~/.conda/envs/eeg/lib/python3.9/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1266
#    1267     # First, search for an existing subplot with a matching spec.
# -> 1268     key = SubplotSpec._from_subplot_args(fig, args)
#    1269
#    1270     for ax in fig.axes:
#
# ~/.conda/envs/eeg/lib/python3.9/site-packages/matplotlib/gridspec.py in _from_subplot_args(figure, args)
#     606         else:
#     607             if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 608                 raise ValueError(
#     609                     f"num must be 1 <= num <= {rows*cols}, not {num!r}")
#     610             i = j = num
#
# ValueError: num must be 1 <= num <= 8, not 9

# %%
# for i,mini in df.groupby(["dataset"]):
#     if len(mini)>4:
#         ax = sns.boxplot(data=mini[['dataset','auc_1','auc_3']], 
#                      palette='Set3', 
#                      linewidth=1.2, 
#                      fliersize=2, 
#                      flierprops=dict(marker='o', markersize=4))
#         plt.show()

# %%
# data = glob.glob(f"outputs3/*_0.png")
# sorted(data)
# for i,row in enumerate(data):
#     plt.figure(figsize=[20,20])
#     plt.imshow(plt.imread(row))
#     plt.title(row)
#     plt.show()

# %%
# !ls outputs/*pkl
# Out:
# outputs/Avocado.pkl	     outputs/playground.pkl
# outputs/California.pkl	     outputs/santander_customer_satisfaction.pkl
# outputs/fetal_health.pkl     outputs/santander.pkl
# outputs/ionosphere.pkl	     outputs/Wids.pkl
# outputs/Medical premium.pkl  outputs/Wine.pkl
# outputs/music.pkl

# %%
with open("outputs/ionosphere.pkl", 'rb') as inp:
    config2 = pickle.load(inp)

# %%
suite.run(train_dataset=config2['history'][0]['ds_train'], test_dataset=config2['history'][0]['ds_test'], model=config2['history'][0]['model'])
# Out:
# Full Suite:   0%|          | 0/35 [00:00<?, ? Check/s]
# VBox(children=(HTML(value='\n        <h1 id="summary_56I1A">Full Suite</h1>\n        <p>\n            The suit…
